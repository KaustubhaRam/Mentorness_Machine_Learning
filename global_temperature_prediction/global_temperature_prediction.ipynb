# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
glt_country=pd.read_csv("GlobalLandTemperaturesByCountry.csv")
glt_city=pd.read_csv("GlobalLandTemperaturesByMajorCity.csv")
glt_state=pd.read_csv("GlobalLandTemperaturesByState.csv")
glt=pd.read_csv("GlobalTemperatures.csv")

# %% [markdown]
# Check nulls

# %%
glt
# Out:
#               dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 0     1750-01-01                   3.034                              3.574
# 1     1750-02-01                   3.083                              3.702
# 2     1750-03-01                   5.626                              3.076
# 3     1750-04-01                   8.490                              2.451
# 4     1750-05-01                  11.573                              2.072
# ...          ...                     ...                                ...
# 3187  2015-08-01                  14.755                              0.072
# 3188  2015-09-01                  12.999                              0.079
# 3189  2015-10-01                  10.801                              0.102
# 3190  2015-11-01                   7.433                              0.119
# 3191  2015-12-01                   5.518                              0.100
#
# ...

# %%
glt.isnull().sum()
# Out:
# dt                                              0
# LandAverageTemperature                         12
# LandAverageTemperatureUncertainty              12
# LandMaxTemperature                           1200
# LandMaxTemperatureUncertainty                1200
# LandMinTemperature                           1200
# LandMinTemperatureUncertainty                1200
# LandAndOceanAverageTemperature               1200
# LandAndOceanAverageTemperatureUncertainty    1200
# dtype: int64

# %%
glt_city
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0       1849-01-01              26.704                          1.435
# 1       1849-02-01              27.434                          1.362
# 2       1849-03-01              28.101                          1.612
# 3       1849-04-01              26.140                          1.387
# 4       1849-05-01              25.427                          1.200
# ...            ...                 ...                            ...
# 239172  2013-05-01              18.979                          0.807
# 239173  2013-06-01              23.522                          0.647
# 239174  2013-07-01              25.251                          1.042
# 239175  2013-08-01              24.528                          0.840
# 239176  2013-09-01                 NaN                            NaN
#
#            City        Country Latitude Longitude
# 0       Abidjan  Côte D'Ivoire    5.63N     3.23W
# ...

# %%
glt_city.isnull().sum()
# Out:
# dt                                   0
# AverageTemperature               11002
# AverageTemperatureUncertainty    11002
# City                                 0
# Country                              0
# Latitude                             0
# Longitude                            0
# dtype: int64

# %%
glt_country
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0       1743-11-01               4.384                          2.294
# 1       1743-12-01                 NaN                            NaN
# 2       1744-01-01                 NaN                            NaN
# 3       1744-02-01                 NaN                            NaN
# 4       1744-03-01                 NaN                            NaN
# ...            ...                 ...                            ...
# 577457  2013-05-01              19.059                          1.022
# 577458  2013-06-01              17.613                          0.473
# 577459  2013-07-01              17.000                          0.453
# 577460  2013-08-01              19.759                          0.717
# 577461  2013-09-01                 NaN                            NaN
#
#          Country
# 0          Åland
# 1          Åland
# 2          Åland
# 3          Åland
# 4          Åland
# ...

# %%
glt_country.isnull().sum()
# Out:
# dt                                   0
# AverageTemperature               32651
# AverageTemperatureUncertainty    31912
# Country                              0
# dtype: int64

# %%
glt_state
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0       1855-05-01              25.544                          1.171
# 1       1855-06-01              24.228                          1.103
# 2       1855-07-01              24.371                          1.044
# 3       1855-08-01              25.427                          1.073
# 4       1855-09-01              25.675                          1.014
# ...            ...                 ...                            ...
# 645670  2013-05-01              21.634                          0.578
# 645671  2013-06-01              24.679                          0.596
# 645672  2013-07-01              29.272                          1.340
# 645673  2013-08-01              29.202                          0.869
# 645674  2013-09-01                 NaN                            NaN
#
#            State Country
# 0           Acre  Brazil
# 1           Acre  Brazil
# 2           Acre  Brazil
# ...

# %%
glt_state.isnull().sum()
# Out:
# dt                                   0
# AverageTemperature               25648
# AverageTemperatureUncertainty    25648
# State                                0
# Country                              0
# dtype: int64

# %%
# glt.dropna(inplace=True)
# glt
# Out:
#               dt  LandAverageTemperature  LandAverageTemperatureUncertainty  \
# 1200  1850-01-01                   0.749                              1.105
# 1201  1850-02-01                   3.071                              1.275
# 1202  1850-03-01                   4.954                              0.955
# 1203  1850-04-01                   7.217                              0.665
# 1204  1850-05-01                  10.004                              0.617
# ...          ...                     ...                                ...
# 3187  2015-08-01                  14.755                              0.072
# 3188  2015-09-01                  12.999                              0.079
# 3189  2015-10-01                  10.801                              0.102
# 3190  2015-11-01                   7.433                              0.119
# 3191  2015-12-01                   5.518                              0.100
#
# ...

# %%
# glt_country.dropna(inplace=True)
# glt_country
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0       1743-11-01               4.384                          2.294
# 5       1744-04-01               1.530                          4.680
# 6       1744-05-01               6.702                          1.789
# 7       1744-06-01              11.609                          1.577
# 8       1744-07-01              15.342                          1.410
# ...            ...                 ...                            ...
# 577456  2013-04-01              21.142                          0.495
# 577457  2013-05-01              19.059                          1.022
# 577458  2013-06-01              17.613                          0.473
# 577459  2013-07-01              17.000                          0.453
# 577460  2013-08-01              19.759                          0.717
#
#          Country
# 0          Åland
# 5          Åland
# 6          Åland
# 7          Åland
# 8          Åland
# ...

# %%
#glt_state.dropna(inplace=True)
#glt_state
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0       1855-05-01              25.544                          1.171
# 1       1855-06-01              24.228                          1.103
# 2       1855-07-01              24.371                          1.044
# 3       1855-08-01              25.427                          1.073
# 4       1855-09-01              25.675                          1.014
# ...            ...                 ...                            ...
# 645669  2013-04-01              15.710                          0.461
# 645670  2013-05-01              21.634                          0.578
# 645671  2013-06-01              24.679                          0.596
# 645672  2013-07-01              29.272                          1.340
# 645673  2013-08-01              29.202                          0.869
#
#            State Country
# 0           Acre  Brazil
# 1           Acre  Brazil
# 2           Acre  Brazil
# ...

# %%
# glt_city.dropna(inplace=True)
# glt_city
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0       1849-01-01              26.704                          1.435
# 1       1849-02-01              27.434                          1.362
# 2       1849-03-01              28.101                          1.612
# 3       1849-04-01              26.140                          1.387
# 4       1849-05-01              25.427                          1.200
# ...            ...                 ...                            ...
# 239171  2013-04-01              12.563                          1.823
# 239172  2013-05-01              18.979                          0.807
# 239173  2013-06-01              23.522                          0.647
# 239174  2013-07-01              25.251                          1.042
# 239175  2013-08-01              24.528                          0.840
#
#            City        Country Latitude Longitude
# 0       Abidjan  Côte D'Ivoire    5.63N     3.23W
# ...

# %%
def fill_nan_bottom_up(df, column):
    if column not in df.columns:
        print(f"Column '{column}' not found in DataFrame.")
        return df

    for i in range(len(df)):
        if pd.isnull(df.loc[i, column]):
            # Get the next 5 non-null values from the current row forward
            valid_values = df[column].iloc[i+1:].dropna().head(5)
            if len(valid_values) > 0:
                # Replace NaN with the mean of the next 5 values (bottom-up)
                df.loc[i, column] = valid_values.mean()
    return df

# %%
cols = [
    "LandAverageTemperature", 
    "LandAverageTemperatureUncertainty", 
    "LandMaxTemperature", 
    "LandMaxTemperatureUncertainty", 
    "LandMinTemperature", 
    "LandMinTemperatureUncertainty", 
    "LandAndOceanAverageTemperature", 
    "LandAndOceanAverageTemperatureUncertainty"
]

# Debugging step: Print the actual columns in your DataFrame
print("Available columns in glt:", glt.columns)

# Loop through the columns and apply the function only if the column exists
for col in cols:
    if col in glt.columns:  # Check if column exists before applying function
        glt = fill_nan_bottom_up(glt, col)
    else:
        print(f"Column {col} not found in DataFrame")
# Out:
# Available columns in glt: Index(['dt', 'LandAverageTemperature', 'LandAverageTemperatureUncertainty',
#        'LandMaxTemperature', 'LandMaxTemperatureUncertainty',
#        'LandMinTemperature', 'LandMinTemperatureUncertainty',
#        'LandAndOceanAverageTemperature',
#        'LandAndOceanAverageTemperatureUncertainty'],
#       dtype='object')
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Kaustubha Ram\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# ...
